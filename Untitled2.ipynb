# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthana0211-s/sketchguess-challenge-105745-105766/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TASK 1

# %%
# Step 1. Imports & Setup

import os
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
# Clone dataset repo
# !git clone https://github.com/shravan-18/Deep-Learning-Lab-Resources.git
# !unzip "/content/Deep-Learning-Lab-Resources/Lab-4/Face Images.zip" -d /content

# Dataset path
data_dir = '/content/Face Images/Final Training Images'
batch_size = 32
target_size = (224, 224)
